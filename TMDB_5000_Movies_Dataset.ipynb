# %% [markdown]
# # Project: TMDB 5000 Movie Dataset Analysis

# %% [markdown]
# # Introduction:
#
# This data set contains information about 5000 movies collected from The Movie Database (TMDb), including user ratings and revenue.
#
# The dataset includes various attributes for each movie such as title, genre, budget, revenue, release date, runtime, popularity, vote average, and vote count.

# %% [markdown]
# # Objective:
#
# The TMDB 5000 Movies dataset is to provide a comprehensive dataset for analyzing trends, patterns, and characteristics within the movie industry.
# It serves as a valuable resource for tasks such as exploratory data analysis, recommendation systems, market analysis.

# %%
#importing libraries
import pandas as pd    # help to manage our dataset
import matplotlib.pyplot as plt   # to plot different charts
import seaborn as sns  # provide statistical plotting features.

# %%
# Load the TMDB movie data from the CSV file into a pandas DataFrame
tmdb_data = pd.read_csv("tmdb_5000_movies.csv")

# %%
# Display the data 
tmdb_data
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
# Display first two data
tmdb_data.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
# Display last 2 data
tmdb_data.tail(2)
# Out:
#       budget                               genres  \
# 4801       0                                   []
# 4802       0  [{"id": 99, "name": "Documentary"}]
#
#                          homepage      id  \
# 4801  http://shanghaicalling.com/  126186
# 4802                          NaN   25975
#
#                                                keywords original_language  \
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#          original_title                                           overview  \
# 4801   Shanghai Calling  When ambitious New York attorney Sam is sent t...
# 4802  My Date with Drew  Ever since the second grade when he first saw ...
#
#       popularity                               production_companies  \
# 4801    0.857008                                                 []
# 4802    1.929883  [{"name": "rusty bear entertainment", "id": 87...
#
# ...

# %%
# It shows the total number of rows and columns from the dataset
tmdb_data.shape
# Out:
# (4803, 20)

# %%
# It shows name of each column
tmdb_data.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count'],
#       dtype='object')

# %%
# It shows the data type of each column
tmdb_data.dtypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
# show information about the dataset
tmdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
# It shows the total number of values in each column
tmdb_data.count()
# Out:
# budget                  4803
# genres                  4803
# homepage                1712
# id                      4803
# keywords                4803
# original_language       4803
# original_title          4803
# overview                4800
# popularity              4803
# production_companies    4803
# production_countries    4803
# release_date            4802
# revenue                 4803
# runtime                 4801
# spoken_languages        4803
# status                  4803
# tagline                 3959
# title                   4803
# vote_average            4803
# vote_count              4803
# dtype: int64

# %%
# It shows the count the number of unique values in each column
tmdb_data.nunique()
# Out:
# budget                   436
# genres                  1175
# homepage                1691
# id                      4803
# keywords                4222
# original_language         37
# original_title          4801
# overview                4800
# popularity              4802
# production_companies    3697
# production_countries     469
# release_date            3280
# revenue                 3297
# runtime                  156
# spoken_languages         544
# status                     3
# tagline                 3944
# title                   4800
# vote_average              71
# vote_count              1609
# dtype: int64

# %%
# It shows unique values with their count
tmdb_data['budget'].value_counts()
# Out:
# budget
# 0           1037
# 20000000     144
# 30000000     128
# 25000000     126
# 40000000     123
#             ...
# 13200000       1
# 14350531       1
# 3100000        1
# 12800000       1
# 9000           1
# Name: count, Length: 436, dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# checking null values
tmdb_data.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Visualizing missing values in the tmdb_data DataFrame
sns.heatmap(tmdb_data.isnull())
# Out:
# <Axes: >

# %%
# Drop columns not required further for analysis
tmdb_data.drop(['homepage', 'keywords', 'original_language', 'original_title', 'tagline', 'overview', 'spoken_languages', 'status'], axis=1, inplace = True) # inplace = true means it modifies the original dataframe and changes are reflects in the original object.
tmdb_data.head(2)
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    285
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
# 1  139.082615  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                     title  vote_average  vote_count
# 0    162.0                                    Avatar           7.2       11800
# 1    169.0  Pirates of the Caribbean: At World's End           6.9        4500

# %%
# Check the null counts again of tmdb_data
tmdb_data.isnull().sum()
# Out:
# budget                  0
# genres                  0
# id                      0
# popularity              0
# production_companies    0
# production_countries    0
# release_date            1
# revenue                 0
# runtime                 2
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
# Drop all missing values
tmdb_data.dropna(axis=0)
# Out:
#          budget                                             genres      id  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   19995
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...     285
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  206647
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...   49026
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...   49529
# ...         ...                                                ...     ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...    9367
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...   72766
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...  231617
# 4801          0                                                 []  126186
# 4802          0                [{"id": 99, "name": "Documentary"}]   25975
#
# ...

# %%
# Check for duplicated data
tmdb_data.duplicated().sum()

# to remove duplicates
#tmdb_data.drop_duplicates()
# Out:
# 0

# %%
# Display data types
tmdb_data.dtypes
# Out:
# budget                    int64
# genres                   object
# id                        int64
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
# convert the data in the 'release_date' column to datetime format.
tmdb_data['release_date'] = pd.to_datetime(tmdb_data['release_date'])
tmdb_data.dtypes
# Out:
# budget                           int64
# genres                          object
# id                               int64
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                          int64
# runtime                        float64
# title                           object
# vote_average                   float64
# vote_count                       int64
# dtype: object

# %% [markdown]
# # Ready to analyze

# %%
# get first two rows
tmdb_data.head(2)
# Out:
#       budget                                             genres     id  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...  19995
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...    285
#
#    popularity                               production_companies  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...
# 1  139.082615  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                     title  vote_average  vote_count
# 0    162.0                                    Avatar           7.2       11800
# 1    169.0  Pirates of the Caribbean: At World's End           6.9        4500

# %%
# Accessing specific columns of the DataFrame
tmdb_data['genres']
# Out:
# 0       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1       [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3       [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4       [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#                               ...
# 4798    [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799    [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800    [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801                                                   []
# 4802                  [{"id": 99, "name": "Documentary"}]
# Name: genres, Length: 4803, dtype: object

# %%
tmdb_data['title']
# Out:
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4                                    John Carter
#                           ...
# 4798                                 El Mariachi
# 4799                                   Newlyweds
# 4800                   Signed, Sealed, Delivered
# 4801                            Shanghai Calling
# 4802                           My Date with Drew
# Name: title, Length: 4803, dtype: object

# %%
# Accessing items in the 'genres' column
tmdb_data['genres'].items()

# %%
# This column has data in zip format which can't be analysed further through present knowledge.these columns are of no use and we need to drop these columns.
tmdb_data.drop(['genres', 'production_companies', 'production_countries'], axis=1, inplace=True)
tmdb_data.head(2)
# Out:
#       budget     id  popularity release_date     revenue  runtime  \
# 0  237000000  19995  150.437577   2009-12-10  2787965087    162.0
# 1  300000000    285  139.082615   2007-05-19   961000000    169.0
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
# Look at the descriptive statistics of the data
tmdb_data.describe()
# Out:
#              budget             id   popularity  \
# count  4.803000e+03    4803.000000  4803.000000
# mean   2.904504e+07   57165.484281    21.492301
# min    0.000000e+00       5.000000     0.000000
# 25%    7.900000e+05    9014.500000     4.668070
# 50%    1.500000e+07   14629.000000    12.921594
# 75%    4.000000e+07   58610.500000    28.313505
# max    3.800000e+08  459488.000000   875.581305
# std    4.072239e+07   88694.614033    31.816650
#
#                         release_date       revenue      runtime  vote_average  \
# count                           4802  4.803000e+03  4801.000000   4803.000000
# mean   2002-12-27 23:45:54.352353280  8.226064e+07   106.875859      6.092172
# min              1916-09-04 00:00:00  0.000000e+00     0.000000      0.000000
# 25%              1999-07-14 00:00:00  0.000000e+00    94.000000      5.600000
# 50%              2005-10-03 00:00:00  1.917000e+07   103.000000      6.200000
# ...

# %% [markdown]
# # Filtering and Sorting

# %%
# Display the movie having runtime > 100 
tmdb_data = tmdb_data[tmdb_data['runtime']>100]
tmdb_data
# Out:
#          budget      id  popularity release_date     revenue  runtime  \
# 0     237000000   19995  150.437577   2009-12-10  2787965087    162.0
# 1     300000000     285  139.082615   2007-05-19   961000000    169.0
# 2     245000000  206647  107.376788   2015-10-26   880674609    148.0
# 3     250000000   49026  112.312950   2012-07-16  1084939099    165.0
# 4     260000000   49529   43.926995   2012-03-07   284139100    132.0
# ...         ...     ...         ...          ...         ...      ...
# 4770     500000   40769    0.123068   2005-03-01           0    109.0
# 4782          0   17345    1.048524   2003-01-01           0    120.0
# 4789          0   39851    1.464566   2004-09-01           0    111.0
# 4792      20000   36095    0.212443   1997-11-06       99000    111.0
# 4800          0  231617    1.444476   2013-10-13           0    120.0
#
#                                          title  vote_average  vote_count
# ...

# %%
# sorting the dataset
tmdb_data.sort_values(by = 'runtime',ascending = True)
# Out:
#         budget      id  popularity release_date   revenue  runtime  \
# 1508  30000000    3594   23.197408   2007-02-23  77566815    101.0
# 3880         0     436    3.027892   2004-01-18         0    101.0
# 1344  36000000   23048   33.926473   2010-03-26  64572262    101.0
# 2659  14600000     137   52.744331   1993-02-11  70906973    101.0
# 3055  10000000   88005   30.863082   2012-06-22   9636289    101.0
# ...        ...     ...         ...          ...       ...      ...
# 2373         0   10549    9.814785   1996-12-25         0    242.0
# 1125  31115000    8095   13.244365   1963-06-12  71000000    248.0
# 1922         0   10655    5.529035   1993-10-08  25000000    254.0
# 2631         0  112430    1.485324   2007-08-05         0    276.0
# 2384  18000000   43434    1.138383   2010-05-19    871279    338.0
#
#                                           title  vote_average  vote_count
# 1508                              The Number 23           6.3        1018
# ...

# %% [markdown]
# # Visualization

# %%
# Plot a histogram of movie runtime
plt.hist(tmdb_data['runtime'], bins=15, edgecolor='black')  # Create a histogram with 15 bins and black edges
plt.xlabel('Runtime')  # Label the x-axis as 'Runtime'
plt.ylabel('Frequency')  # Label the y-axis as 'Frequency'
plt.title('Distribution of Movie Runtimes')  # Set the title of the plot
plt.show()  # Display the plot

# %% [markdown]
# This graph provides insight into the distribution of movie runtimes within the dataset, showing the most common durations and the overall spread of movie lengths.

# %%
# Visualize the distribution of original titles in movies
# Count the occurrences of each original title and select the top 10
language_counts = tmdb_data['runtime'].value_counts().head(10)

# Create a bar plot with seaborn
sns.barplot(x=language_counts.index, y=language_counts.values, palette='viridis')

# Label the x-axis as 'runtime' and the y-axis as 'Count'
plt.xlabel('runtime')
plt.ylabel('Count')

# Set the title of the plot
plt.title('Top 10 Original titles in Movies')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.show()

# %% [markdown]
# This graph provides a visual representation of the distribution of movie runtimes for the top 10 original titles, allowing for easy comparison of runtime frequencies across different titles.
#
# It counts the occurrences of each movie runtime value and selects the top 10 most common runtimes

# %%
# Plotting a scatter plot of budget vs. revenue using Seaborn
sns.scatterplot(x='budget', y='revenue',data=tmdb_data)  # Scatter plot using Seaborn

# Adding labels and title to the plot
plt.xlabel('Budget')  # Label for the x-axis as 'budget'
plt.ylabel('Revenue')  # Label for the y-axis as 'revenue'
plt.title('Budget vs. Revenue')  # Title of the plot

# Displaying the plot
plt.show()  # Show the plot

# %% [markdown]
# This graph provides insights into the relationship between movie budget and revenue, highlighting the general trend as well as the variability in revenue across different budget levels.

# %%
# Plot a line plot of average revenue over release years
# Grouping the data by release year and calculating the average revenue
avg_revenue_by_year = tmdb_data.groupby(tmdb_data['release_date'].dt.year)['revenue'].mean()

# Plotting the line plot
plt.plot(avg_revenue_by_year.index, avg_revenue_by_year.values, marker='o', linestyle='-')

# Adding labels and title
plt.xlabel('Release Year')
plt.ylabel('Average Revenue')
plt.title('Average Revenue Over Release Years')

# Displaying the plot
plt.show()

# %% [markdown]
#  This graph provides insights into the average revenue trends in the movie industry over the years, highlighting both the general trend of increasing revenue and the year-to-year variability.
